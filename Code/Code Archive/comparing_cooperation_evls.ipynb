# %%
# %run imports.ipynb
# %run information_conditions.ipynb import Information_Conditions
# %run base_ecopg.ipynb import BaseEcologicalPublicGood
# %run helper_functions.ipynb import *
# %run simulation_and_results_functions.ipynb import *

# %%
'''ecopgg only social'''

ecopg = BaseEcologicalPublicGood()
information_condition_instance = Information_Conditions(ecopg, mode="both_state_and_action_information")

mae_ecopg = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 0.98)


results_tuple_list = run_simulation_across_conditions(
    mae = mae_ecopg, 
    mode = "both_state_and_action_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)

# print([results_tuple_list[i][1] for i in range(len(results_tuple_list))])

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       3 ecopg = BaseEcologicalPublicGood()
#       4 information_condition_instance = Information_Conditions(ecopg, mode="both_state_and_action_information")
# ----> 6 mae_ecopg = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 0.98)
#       9 results_tuple_list = run_simulation_across_conditions(
#      10     mae = mae_ecopg,
#      11     mode = "both_state_and_action_information",
#      12     num_samples = 7,
#      13     exclude_degraded_state_for_average_cooperation = False
#      14 )
#      16 # print([results_tuple_list[i][1] for i in range(len(results_tuple_list))])
#
# NameError: name 'POstratAC_eps' is not defined

# %%
'''ecopgg only social'''

ecopg = BaseEcologicalPublicGood()
information_condition_instance = Information_Conditions(ecopg, mode="only_action_history_information")
mae_ecopg = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 0.98)


results_tuple_list = run_simulation_across_conditions(
    mae = mae_ecopg, 
    mode = "only_action_history_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)

# print([results_tuple_list[i][1] for i in range(len(results_tuple_list))])

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 ecopg = BaseEcologicalPublicGood()
#       4 information_condition_instance = Information_Conditions(ecopg, mode="only_action_history_information")
# ----> 5 mae_ecopg = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 0.98)
#       8 results_tuple_list = run_simulation_across_conditions(
#       9     mae = mae_ecopg,
#      10     mode = "only_action_history_information",
#      11     num_samples = 7,
#      12     exclude_degraded_state_for_average_cooperation = False
#      13 )
#      15 # print([results_tuple_list[i][1] for i in range(len(results_tuple_list))])
#
# NameError: name 'POstratAC_eps' is not defined

# %%
f = ecopg.f[1]
c = ecopg.c[1]

socdi = SocialDilemma(R= f*c - c, T= f*c/2, S= f*c/2 - c, P= 0.0)
memo1pd = HistoryEmbedded(socdi, h = (1, 1, 1))

print(socdi.R)
# Out:
# <bound method SocialDilemma.RewardTensor of SocialDilemma_3.0_1.0_0.0_-2.0>

# %%
'''memo1pd where the payoffs are the same as ecopg propso'''
mae_memo1pd = POstratAC_eps(env=memo1pd, learning_rates=0.05, discount_factors= 0.98)


results_tuple_list = run_simulation_across_conditions(
    mae = mae_memo1pd, 
    mode = "only_action_history_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)


results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)

'''no coop'''
# Out:
# (np.float64(0.0),   Classification  MedianTimetoReach  Percentage
# 0      Defection              119.5       100.0)
# 'no coop'

# %%
'''ecopgg no transition to degraded state'''

ecopg_no_transistion_to_degraded_state = BaseEcologicalPublicGood(qc = 0.0)
information_condition_instance = Information_Conditions(ecopg_no_transistion_to_degraded_state, mode="only_action_history_information")
mae_ecopg = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 0.98)


# Data storage

# print(f"\nMode: {mode}")

results_tuple_list = run_simulation_across_conditions(
    mae = mae_ecopg, 
    mode = "only_action_history_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)

'''No coop again. (small time difference with memo1pd)'''
# Out:
# (np.float64(0.0),   Classification  MedianTimetoReach  Percentage
# 0      Defection              121.0       100.0)
# 'No coop again. (small time difference with memo1pd)'

# %%
'''high discount factor, still no coop (for this R,T,S,P  values).
 Whne socdi = SocialDilemma(R=1.0, T= 3, S= -2, P=0.0) 0.99 is enough to acheive coop""
 '''

mae_memo1pd_high_discount_factor = POstratAC(env=memo1pd, learning_rates=0.05, discount_factors= 0.99999)


# Data storage

# print(f"\nMode: {mode}")

results_tuple_list = run_simulation_across_conditions(
    mae = mae_memo1pd_high_discount_factor, 
    mode = "only_action_history_information",
    num_samples = 15, 
    exclude_degraded_state_for_average_cooperation = False
)

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)


''''''
# Out:
# (np.float64(0.0),   Classification  MedianTimetoReach  Percentage
# 0      Defection              124.0       100.0)
# ''

# %%
'''ecopgg withd degradation and high discount factor'''

ecopg = BaseEcologicalPublicGood()
information_condition_instance = Information_Conditions(ecopg, mode="only_action_history_information")
mae_ecopg_high_discount_factor = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 1 - 1e-5)


# Data storage

# print(f"\nMode: {mode}")

results_tuple_list = run_simulation_across_conditions(
    mae = mae_ecopg_high_discount_factor, 
    mode = "only_action_history_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)

'''cooperation acheibed at 1e-5 which is a lower treshold compared to the memo1pd or the ecopg with no transition case'''
'''cares about preventing degradation despite not having infotrmation about the enviornmatalo state'''
# Out:
# (np.float64(0.427),   Classification  MedianTimetoReach  Percentage
# 0    Cooperation               87.0        10.7
# 1      Defection               65.0        39.3
# 2          Mixed              161.5        50.0)
# 'cares about preventing degradation despite not having infotrmation about the enviornmatalo state'

# %%
'''ecopgg with degradation and high discount factor, but no transition to degraded state'''


ecopg = BaseEcologicalPublicGood(qc = 0.0)
information_condition_instance = Information_Conditions(ecopg, mode="only_action_history_information")
mae_ecopg_high_discount_factor = POstratAC_eps(env=information_condition_instance, learning_rates=0.05, discount_factors= 0.99999)


# Data storage

# print(f"\nMode: {mode}")

results_tuple_list = run_simulation_across_conditions(
    mae = mae_ecopg_high_discount_factor, 
    mode = "only_action_history_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)

'''no cooperation. no environmantal reciorpcoty'''

# %%
''' a very high discount factor (at least 1 - 1e-8) is needed for acheiving coop""
 '''

mae_memo1pd_high_discount_factor = POstratAC(env=memo1pd, learning_rates=0.05, discount_factors= 1 - 1e-6)


# Data storage

# print(f"\nMode: {mode}")

results_tuple_list = run_simulation_across_conditions(
    mae = mae_memo1pd_high_discount_factor, 
    mode = "only_action_history_information",
    num_samples = 7, 
    exclude_degraded_state_for_average_cooperation = False
)

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)

make_plots(memo1pd, mae_memo1pd_high_discount_factor, results_tuple_list)
''''''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 ''' a very high discount factor (at least 1 - 1e-8) is needed for acheiving coop""
#       2  '''
# ----> 4 mae_memo1pd_high_discount_factor = POstratAC(env=memo1pd, learning_rates=0.05, discount_factors= 1 - 1e-6)
#       7 # Data storage
#       8
#       9 # print(f"\nMode: {mode}")
#      11 results_tuple_list = run_simulation_across_conditions(
#      12     mae = mae_memo1pd_high_discount_factor,
#      13     mode = "only_action_history_information",
#      14     num_samples = 7,
#      15     exclude_degraded_state_for_average_cooperation = False
#      16 )
#
# NameError: name 'POstratAC' is not defined

# %%
'''When temptation is high and sucker's payoff worse, the discount factor needs to be very high (at least 1 - 10e-9) to acheive coop.'''


f = ecopg.f[1]
c = ecopg.c[1]
r = f*c - c  #1
t = f*c/2    #3
s = f*c/2 - c  #-2
p = 0.0     #0


# socdi_x2 = SocialDilemma(R=1.0, T=1.2, S=-0.5, P=0.0)
socdi_x2 = SocialDilemma(R=1.0, T= 2 , S= -1.5 , P=0.0)

memo1pd_x2 = HistoryEmbedded(socdi_x2, h = (1, 1, 1))

mae_memo1pd_x2_high_discount_factor = POstratAC(env=memo1pd_x2, learning_rates=0.05, discount_factors= 1 - 1e-9)


# Data storage

# print(f"\nMode: {mode}")

results_tuple_list = run_simulation_across_conditions(
    mae = mae_memo1pd_x2_high_discount_factor, 
    mode = "only_action_history_information",
    num_samples = 20, 
    exclude_degraded_state_for_average_cooperation = False
)


print(results_tuple_list)

results_summary = get_cooperation_time_summary(results_tuple_list)

print(results_summary)
# Out:
# [{'avg_coop': Array(0.44943815, dtype=float32), 'time_to_reach': 2, 'final_point': array([[[0.00207474, 0.99792522],
#         [0.42460698, 0.57539302],
#         [0.9930436 , 0.00695635],
#         [0.19261947, 0.80738056]],
#
#        [[0.2075464 , 0.79245359],
#         [0.31607893, 0.6839211 ],
#         [0.58865124, 0.41134879],
#         [0.70968229, 0.29031765]]])}, {'avg_coop': Array(0.46297112, dtype=float32), 'time_to_reach': 8, 'final_point': array([[[0.34607792, 0.65392208],
#         [0.56666309, 0.43333691],
#         [0.07380243, 0.92619753],
#         [0.89163303, 0.10836691]],
#
#        [[0.77037907, 0.2296209 ],
#         [0.01838517, 0.98161483],
#         [0.42141634, 0.57858372],
#         [0.56968975, 0.43031022]]])}, {'avg_coop': Array(0.6069955, dtype=float32), 'time_to_reach': 5, 'final_point': array([[[0.94897622, 0.05102374],
#         [0.8040573 , 0.19594271],
#         [0.5755837 , 0.42441633],
#         [0.88211465, 0.11788532]],
#
#        [[0.05406837, 0.94593167],
#         [0.64861012, 0.35138983],
#         [0.09529919, 0.90470082],
#         [0.05745908, 0.94254094]]])}, {'avg_coop': Array(0.27216586, dtype=float32), 'time_to_reach': 4, 'final_point': array([[[0.31475875, 0.68524128],
#         [0.63196373, 0.3680363 ],
#         [0.3270154 , 0.67298454],
#         [0.0467091 , 0.95329088]],
#
#        [[0.26121345, 0.73878658],
#         [0.33132824, 0.66867173],
#         [0.00517522, 0.99482471],
#         [0.44576338, 0.55423665]]])}, {'avg_coop': Array(0.35523954, dtype=float32), 'time_to_reach': 35, 'final_point': array([[[0.28459293, 0.71540713],
#         [0.11226757, 0.88773245],
#         [0.61134714, 0.38865289],
#         [0.24910969, 0.75089031]],
#
#        [[0.85318714, 0.1468129 ],
#         [0.16052611, 0.83947384],
#         [0.40011033, 0.5998897 ],
#         [0.33759835, 0.66240162]]])}, {'avg_coop': Array(0.34896326, dtype=float32), 'time_to_reach': 9, 'final_point': array([[[0.63714665, 0.36285332],
#         [0.04544562, 0.95455438],
#         [0.00864375, 0.99135625],
#         [0.28767371, 0.71232629]],
#
#        [[0.65972793, 0.34027201],
#         [0.23121065, 0.76878929],
#         [0.53521746, 0.46478254],
#         [0.49673903, 0.50326097]]])}, {'avg_coop': Array(0.4672945, dtype=float32), 'time_to_reach': 1, 'final_point': array([[[0.45588302, 0.54411698],
#         [0.88145555, 0.11854445],
#         [0.27928365, 0.72071635],
#         [0.55838838, 0.44161162]],
#
#        [[0.36363981, 0.63636019],
#         [0.24736559, 0.75263441],
#         [0.28736386, 0.71263614],
#         [0.15389474, 0.84610526]]])}, {'avg_coop': Array(0.46597767, dtype=float32), 'time_to_reach': 8, 'final_point': array([[[0.39605826, 0.60394174],
#         [0.73086697, 0.26913303],
#         [0.43892339, 0.56107664],
#         [0.79216278, 0.20783722]],
#
#        [[0.29622424, 0.70377576],
#         [0.36342636, 0.63657361],
#         [0.16395585, 0.83604419],
#         [0.1243056 , 0.87569439]]])}, {'avg_coop': Array(0.2070756, dtype=float32), 'time_to_reach': 1, 'final_point': array([[[0.19830631, 0.80169369],
#         [0.01885728, 0.98114272],
#         [0.12242818, 0.87757182],
#         [0.14517085, 0.85482915]],
#
#        [[0.00119971, 0.99880029],
#         [0.66771187, 0.33228813],
#         [0.10238054, 0.89761946],
#         [0.31518738, 0.68481262]]])}, {'avg_coop': Array(0.52107304, dtype=float32), 'time_to_reach': 1, 'final_point': array([[[0.56706986, 0.43293014],
#         [0.29329733, 0.70670267],
#         [0.57979897, 0.42020103],
#         [0.02098217, 0.97901783]],
#
#        [[0.8464844 , 0.1535156 ],
#         [0.29361969, 0.70638031],
#         [0.46734265, 0.53265735],
#         [0.97049714, 0.02950286]]])}, {'avg_coop': Array(0.5803008, dtype=float32), 'time_to_reach': 6, 'final_point': array([[[0.76780093, 0.23219907],
#         [0.41985369, 0.58014625],
#         [0.0777844 , 0.92221558],
#         [0.91039568, 0.08960433]],
#
#        [[0.8071087 , 0.19289128],
#         [0.75304484, 0.24695519],
#         [0.26924947, 0.7307505 ],
#         [0.37089214, 0.62910783]]])}, {'avg_coop': Array(0.5665919, dtype=float32), 'time_to_reach': 6, 'final_point': array([[[0.00796997, 0.99203002],
#         [0.30267975, 0.69732022],
#         [0.16525878, 0.83474123],
#         [0.7021172 , 0.29788283]],
#
#        [[0.97108918, 0.02891085],
#         [0.97711724, 0.02288274],
#         [0.9907909 , 0.00920911],
#         [0.64539164, 0.35460839]]])}, {'avg_coop': Array(0.5617112, dtype=float32), 'time_to_reach': 18, 'final_point': array([[[0.892124  , 0.107876  ],
#         [0.33703971, 0.66296029],
#         [0.76090449, 0.23909549],
#         [0.75184137, 0.24815863]],
#
#        [[0.23276938, 0.76723063],
#         [0.7751931 , 0.22480695],
#         [0.58982843, 0.41017157],
#         [0.00275134, 0.99724871]]])}, {'avg_coop': Array(0.6006571, dtype=float32), 'time_to_reach': 3, 'final_point': array([[[0.62708771, 0.37291229],
#         [0.4122372 , 0.58776277],
#         [0.34650251, 0.65349746],
#         [0.48712224, 0.51287776]],
#
#        [[0.74688309, 0.25311688],
#         [0.96412468, 0.03587532],
#         [0.67110372, 0.32889634],
#         [0.63488495, 0.36511508]]])}, {'avg_coop': Array(0.48844272, dtype=float32), 'time_to_reach': 8, 'final_point': array([[[0.55078328, 0.44921675],
#         [0.13373829, 0.86626172],
#         [0.46475285, 0.53524715],
#         [0.58632904, 0.41367093]],
#
#        [[0.20759948, 0.79240054],
#         [0.91205138, 0.08794863],
#         [0.23235106, 0.76764894],
#         [0.90946108, 0.09053894]]])}, {'avg_coop': Array(0.6783775, dtype=float32), 'time_to_reach': 9, 'final_point': array([[[0.89466459, 0.10533539],
#         [0.50433904, 0.49566099],
#         [0.85331357, 0.14668643],
#         [0.49567991, 0.50432009]],
#
#        [[0.56484032, 0.43515974],
#         [0.8693164 , 0.13068354],
#         [0.43744752, 0.56255251],
#         [0.38389561, 0.61610442]]])}, {'avg_coop': Array(0.35665214, dtype=float32), 'time_to_reach': 2, 'final_point': array([[[0.10005371, 0.89994627],
#         [0.17907129, 0.82092869],
#         [0.69599414, 0.30400589],
#         [0.38924733, 0.6107527 ]],
#
#        [[0.4278869 , 0.57211304],
#         [0.15687887, 0.84312111],
#         [0.05176508, 0.94823498],
#         [0.60018891, 0.39981109]]])}, {'avg_coop': Array(0.2895378, dtype=float32), 'time_to_reach': 2, 'final_point': array([[[0.30779466, 0.69220537],
#         [0.310958  , 0.68904203],
#         [0.15890317, 0.84109682],
#         [0.32477701, 0.67522293]],
#
#        [[0.58696169, 0.41303834],
#         [0.11586907, 0.88413095],
#         [0.48926616, 0.51073384],
#         [0.2388052 , 0.76119477]]])}, {'avg_coop': Array(0.33359808, dtype=float32), 'time_to_reach': 6, 'final_point': array([[[4.20603976e-02, 9.57939625e-01],
#         [2.59335548e-01, 7.40664482e-01],
#         [5.55536926e-01, 4.44463015e-01],
#         [3.13950777e-01, 6.86049223e-01]],
#
#        [[5.30306458e-01, 4.69693542e-01],
#         [2.44368002e-05, 9.99975562e-01],
#         [2.80531477e-02, 9.71946836e-01],
#         [6.51781142e-01, 3.48218858e-01]]])}, {'avg_coop': Array(0.44006866, dtype=float32), 'time_to_reach': 8, 'final_point': array([[[0.73594922, 0.26405078],
#         [0.12991154, 0.87008846],
#         [0.33526447, 0.6647355 ],
#         [0.09690913, 0.90309089]],
#
#        [[0.09297334, 0.90702671],
#         [0.41161186, 0.5883882 ],
#         [0.73202258, 0.26797745],
#         [0.69851828, 0.30148175]]])}]
# (np.float64(0.453),   Classification  MedianTimetoReach  Percentage
# 0          Mixed                6.0       100.0)

# %%
'''check the role of game payoff in this effevt'''
