# %%
# %run imports.ipynb
# %run information_conditions.ipynb import Information_Conditions
# %run base_ecopg.ipynb import BaseEcologicalPublicGood%run base_ecopg.ipynb
# %run base_ecopg.ipynb import all_information_modes
# %run helper_functions.ipynb import *
# %run simulation_and_results_functions.ipynb import *

# %%
#Just to initialise a random startegy for the state set. This will be used to get the average policy for the given observation set

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       1 #| export
#       3 for mode in ['complete','social', 'ecological','none']:
#       4     #for each information condition get the average policy for the given observation set and plot the flow diagram
# ----> 7     information_condition_instance = Information_Conditions(ecopg, mode=mode)
#       8     num_observed_states = len(information_condition_instance.Oset[0])
#       9     x, y = ([0], list(range(num_observed_states)), [0]), ([1], list(range(num_observed_states)), [0])
#
# File ~\AppData\Local\Temp\ipykernel_7408\2191314776.py:9, in Information_Conditions.__init__(self, ecopg, mode)
#       6 super().__init__(ecopg, h=(1, 1, 1))
#       8 self.mode = mode
# ----> 9 self.configure_information_condition()
#
# File ~\AppData\Local\Temp\ipykernel_7408\2191314776.py:25, in Information_Conditions.configure_information_condition(self)
#      23     self._configure_state_action()
#      24 else:
# ---> 25     raise ValueError("Invalid mode..")
#      26 # self._print_configuration()
#      28 self.Q = self.O.shape[2]
#
# ValueError: Invalid mode..
